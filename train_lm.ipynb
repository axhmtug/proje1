# %%
import os
import math
import sentencepiece as spm
import torch
import torch.nn as nn
from torch.nn import functional as F

DATA_FILE = "smll3.txt"       
TOKENIZER_MODEL = "tokenizer.model"

if not os.path.exists(TOKENIZER_MODEL):
    spm.SentencePieceTrainer.Train(
        input=DATA_FILE,
        model_prefix="tokenizer",
        vocab_size=6000,              
        model_type="bpe",
        character_coverage=1.0,
        byte_fallback=True
    )

sp = spm.SentencePieceProcessor(model_file=TOKENIZER_MODEL)


class RMSNorm(nn.Module):
    def __init__(self, dim, eps=1e-6):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(dim))
        self.eps = eps

    def forward(self, x):
        norm = x.norm(2, dim=-1, keepdim=True)
        rms = norm / math.sqrt(x.size(-1))
        return self.weight * x / (rms + self.eps)

def rotary_embedding(q, k, seq_len, dim):
    pos = torch.arange(seq_len, device=q.device).float()
    freqs = 1.0 / (10000 ** (torch.arange(0, dim, 2, device=q.device).float() / dim))
    angles = torch.einsum('i,j->ij', pos, freqs)
    emb = torch.cat([angles.sin(), angles.cos()], dim=-1)
    emb = emb.unsqueeze(0).unsqueeze(2)

    q_embed = torch.cat([
        q[..., :dim//2] * emb[..., dim//2:] + q[..., dim//2:] * emb[..., :dim//2],
        q[..., :dim//2] * emb[..., :dim//2] - q[..., dim//2:] * emb[..., dim//2:]
    ], dim=-1)

    k_embed = torch.cat([
        k[..., :dim//2] * emb[..., dim//2:] + k[..., dim//2:] * emb[..., :dim//2],
        k[..., :dim//2] * emb[..., :dim//2] - k[..., dim//2:] * emb[..., dim//2:]
    ], dim=-1)

    return q_embed, k_embed

class MultiQueryAttention(nn.Module):
    def __init__(self, dim, heads):
        super().__init__()
        self.heads = heads
        self.dim = dim
        self.head_dim = dim // heads

        self.q = nn.Linear(dim, dim)
        self.k = nn.Linear(dim, self.head_dim)
        self.v = nn.Linear(dim, self.head_dim)
        self.o = nn.Linear(dim, dim)

    def forward(self, x):
        B, T, C = x.shape

        q = self.q(x).view(B, T, self.heads, self.head_dim)
        k = self.k(x).unsqueeze(2)
        v = self.v(x).unsqueeze(2)

        q, k = rotary_embedding(q, k, T, self.head_dim)

        att = torch.einsum("bthd,bThd->bhtT", q, k) / math.sqrt(self.head_dim)
        att = att.masked_fill(torch.triu(torch.ones(T, T), 1).bool().to(x.device), float('-inf'))
        att = att.softmax(dim=-1)

        out = torch.einsum("bhtT,bThd->bthd", att, v)
        out = out.reshape(B, T, C)
        return self.o(out)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden):
        super().__init__()
        self.w1 = nn.Linear(dim, hidden)
        self.w2 = nn.Linear(hidden, dim)
        self.gate = nn.Sigmoid()

    def forward(self, x):
        return self.w2(torch.relu(self.w1(x)))

class Block(nn.Module):
    def __init__(self, dim, heads):
        super().__init__()
        self.norm1 = RMSNorm(dim)
        self.attn = MultiQueryAttention(dim, heads)
        self.norm2 = RMSNorm(dim)
        self.ff = FeedForward(dim, dim * 4)

    def forward(self, x):
        x = x + self.attn(self.norm1(x))
        x = x + self.ff(self.norm2(x))
        return x

class TinyLM(nn.Module):
    def __init__(self, vocab, dim=256, layers=6, heads=4, max_len=256):
        super().__init__()
        self.tok = nn.Embedding(vocab, dim)
        self.pos = nn.Embedding(max_len, dim)
        self.blocks = nn.ModuleList([Block(dim, heads) for _ in range(layers)])
        self.norm = RMSNorm(dim)
        self.out = nn.Linear(dim, vocab)

    def forward(self, x):
        B, T = x.shape
        h = self.tok(x) + self.pos(torch.arange(T, device=x.device))
        for blk in self.blocks:
            h = blk(h)
        h = self.norm(h)
        return self.out(h)


with open(DATA_FILE, "r", encoding="utf-8") as f:
    text = f.read()

ids = sp.encode(text, out_type=int)
ids = torch.tensor(ids, dtype=torch.long)
print("Tokens:", len(ids))



VOCAB = sp.get_piece_size()
BATCH = 8
SEQ = 128
EPOCHS = 3
LR = 1e-3

model = TinyLM(VOCAB).to("cpu")
opt = torch.optim.AdamW(model.parameters(), lr=LR)
loss_fn = nn.CrossEntropyLoss()

def get_batch():
    ix = torch.randint(0, len(ids) - SEQ - 1, (BATCH,))
    x = torch.stack([ids[i:i+SEQ] for i in ix])
    y = torch.stack([ids[i+1:i+SEQ+1] for i in ix])
    return x, y

for epoch in range(EPOCHS):
    for step in range(2000):  
        x, y = get_batch()
        logits = model(x)
        loss = loss_fn(logits.view(-1, VOCAB), y.view(-1))

        opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()

        if step % 200 == 0:
            print(f"epoch {epoch} step {step}: loss {loss.item():.4f}")

torch.save(model.state_dict(), "tinyLM.pt")
print("model kayit edildi: tinyLM.pt")
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: smll3.txt
#   input_format:
#   model_prefix: tokenizer
#   model_type: BPE
#   vocab_size: 6000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 1
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: smll3.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 150676 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x00>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x01>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x02>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x03>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x04>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x05>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x06>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x07>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x08>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x09>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x0A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x0B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x0C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x0D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x0E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x0F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x10>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x11>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x12>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x13>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x14>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x15>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x16>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x17>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x18>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x19>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x1A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x1B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x1C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x1D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x1E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x1F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x20>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x21>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x22>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x23>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x24>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x25>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x26>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x27>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x28>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x29>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x2A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x2B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x2C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x2D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x2E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x2F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x30>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x31>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x32>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x33>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x34>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x35>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x36>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x37>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x38>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x39>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x3A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x3B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x3C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x3D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x3E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x3F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x40>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x41>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x42>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x43>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x44>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x45>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x46>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x47>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x48>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x49>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x4A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x4B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x4C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x4D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x4E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x4F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x50>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x51>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x52>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x53>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x54>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x55>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x56>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x57>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x58>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x59>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x5A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x5B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x5C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x5D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x5E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x5F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x60>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x61>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x62>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x63>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x64>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x65>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x66>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x67>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x68>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x69>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x6A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x6B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x6C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x6D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x6E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x6F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x70>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x71>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x72>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x73>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x74>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x75>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x76>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x77>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x78>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x79>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x7A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x7B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x7C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x7D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x7E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x7F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x80>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x81>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x82>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x83>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x84>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x85>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x86>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x87>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x88>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x89>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x8A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x8B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x8C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x8D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x8E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x8F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x90>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x91>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x92>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x93>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x94>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x95>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x96>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x97>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x98>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x99>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x9A>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x9B>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x9C>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x9D>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x9E>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0x9F>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA0>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA1>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA2>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA3>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA4>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA5>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA6>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA7>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA8>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xA9>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xAA>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xAB>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xAC>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xAD>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xAE>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xAF>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB0>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB1>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB2>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB3>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB4>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB5>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB6>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB7>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB8>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xB9>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xBA>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xBB>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xBC>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xBD>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xBE>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xBF>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC0>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC1>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC2>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC3>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC4>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC5>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC6>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC7>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC8>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xC9>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xCA>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xCB>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xCC>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xCD>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xCE>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xCF>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD0>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD1>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD2>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD3>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD4>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD5>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD6>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD7>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD8>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xD9>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xDA>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xDB>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xDC>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xDD>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xDE>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xDF>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE0>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE1>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE2>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE3>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE4>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE5>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE6>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE7>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE8>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xE9>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xEA>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xEB>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xEC>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xED>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xEE>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xEF>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF0>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF1>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF2>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF3>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF4>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF5>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF6>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF7>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF8>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xF9>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xFA>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xFB>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xFC>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xFD>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xFE>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <0xFF>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=14341580
# trainer_interface.cc(562) LOG(INFO) Alphabet size=70
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 150676 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 150676
# trainer_interface.cc(611) LOG(INFO) Done! 23763
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=327120 min_freq=1
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104035 size=20 all=1301 active=1231 piece=ee
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53843 size=40 all=1898 active=1828 piece=us
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34916 size=60 all=2442 active=2372 piece=▁h
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26496 size=80 all=3004 active=2934 piece=ct
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22414 size=100 all=3399 active=3329 piece=▁when
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21809 min_freq=679
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18752 size=120 all=3938 active=1539 piece=▁so
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15484 size=140 all=4421 active=2022 piece=ce
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13296 size=160 all=4696 active=2297 piece=▁but
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11363 size=180 all=4921 active=2522 piece=hing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9917 size=200 all=5178 active=2779 piece=▁enjoy
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9903 min_freq=718
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8952 size=220 all=5386 active=1204 piece=ell
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8201 size=240 all=5735 active=1553 piece=▁sm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7444 size=260 all=5929 active=1747 piece=ents
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6853 size=280 all=6186 active=2004 piece=▁very
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6368 size=300 all=6508 active=2326 piece=▁even
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6306 min_freq=665
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5744 size=320 all=6616 active=1106 piece=ause
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5381 size=340 all=6743 active=1233 piece=ree
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4896 size=360 all=6980 active=1470 piece=▁go
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4634 size=380 all=7140 active=1630 piece=rat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4378 size=400 all=7391 active=1881 piece=▁try
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4369 min_freq=586
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4165 size=420 all=7773 active=1382 piece=▁wish
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3764 size=440 all=7971 active=1580 piece=▁share
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3510 size=460 all=8253 active=1862 piece=▁clean
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3306 size=480 all=8424 active=2033 piece=▁Som
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3079 size=500 all=8529 active=2138 piece=▁fl
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3068 min_freq=515
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2913 size=520 all=8695 active=1149 piece=▁sadness
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2718 size=540 all=8791 active=1245 piece=▁mind
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2548 size=560 all=8989 active=1443 piece=ome
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2348 size=580 all=9116 active=1570 piece=ward
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2240 size=600 all=9227 active=1681 piece=▁spir
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2231 min_freq=452
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2163 size=620 all=9348 active=1119 piece=ag
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2089 size=640 all=9551 active=1322 piece=▁op
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1994 size=660 all=9660 active=1431 piece=ire
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1887 size=680 all=9763 active=1534 piece=esh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1793 size=700 all=9888 active=1659 piece=▁park
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1790 min_freq=400
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1712 size=720 all=10063 active=1175 piece=▁clear
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1621 size=740 all=10260 active=1372 piece=isten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1532 size=760 all=10324 active=1436 piece=▁guess
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1464 size=780 all=10402 active=1514 piece=▁tast
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1427 size=800 all=10509 active=1621 piece=▁ind
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1421 min_freq=356
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1380 size=820 all=10571 active=1056 piece=▁having
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1324 size=840 all=10744 active=1229 piece=▁des
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1266 size=860 all=10897 active=1382 piece=▁reflecting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1191 size=880 all=10982 active=1467 piece=▁la
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1155 size=900 all=11108 active=1593 piece=▁Thank
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1154 min_freq=317
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1119 size=920 all=11205 active=1096 piece=▁experiences
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1064 size=940 all=11290 active=1181 piece=▁effort
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1018 size=960 all=11385 active=1276 piece=▁looks
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=986 size=980 all=11472 active=1363 piece=oor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=945 size=1000 all=11543 active=1434 piece=▁ease
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=945 min_freq=284
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=913 size=1020 all=11662 active=1120 piece=▁break
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=880 size=1040 all=11738 active=1196 piece=▁smile
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=846 size=1060 all=11834 active=1292 piece=▁disgusting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=831 size=1080 all=11899 active=1357 piece=▁year
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=813 size=1100 all=12032 active=1490 piece=▁surprises
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=812 min_freq=258
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=785 size=1120 all=12110 active=1079 piece=ural
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=761 size=1140 all=12225 active=1194 piece=▁gets
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=726 size=1160 all=12308 active=1277 piece=▁where
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=701 size=1180 all=12370 active=1339 piece=ount
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=680 size=1200 all=12434 active=1403 piece=▁busy
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=679 min_freq=234
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=667 size=1220 all=12527 active=1093 piece=▁hab
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=655 size=1240 all=12570 active=1136 piece=ince
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=633 size=1260 all=12671 active=1237 piece=▁reas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=614 size=1280 all=12714 active=1280 piece=▁strugg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=595 size=1300 all=12770 active=1336 piece=oring
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=594 min_freq=215
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=576 size=1320 all=12815 active=1034 piece=▁reg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=566 size=1340 all=12889 active=1108 piece=▁solutions
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=552 size=1360 all=12945 active=1164 piece=▁prot
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=530 size=1380 all=13046 active=1265 piece=▁advent
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=521 size=1400 all=13091 active=1310 piece=▁unapp
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=520 min_freq=200
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=503 size=1420 all=13240 active=1145 piece=▁bod
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=488 size=1440 all=13313 active=1218 piece=▁There
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=480 size=1460 all=13346 active=1251 piece=▁unexpectedly
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=469 size=1480 all=13372 active=1277 piece=▁carry
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=457 size=1500 all=13403 active=1308 piece=▁coming
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=456 min_freq=184
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=444 size=1520 all=13466 active=1064 piece=ife
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=434 size=1540 all=13521 active=1119 piece=▁atmosp
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=427 size=1560 all=13565 active=1163 piece=▁pass
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=416 size=1580 all=13602 active=1200 piece=▁cloud
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=408 size=1600 all=13663 active=1261 piece=▁looked
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=407 min_freq=168
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=396 size=1620 all=13684 active=1022 piece=ork
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=386 size=1640 all=13731 active=1069 piece=llow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=377 size=1660 all=13769 active=1107 piece=▁fre
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=367 size=1680 all=13838 active=1176 piece=▁unset
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=358 size=1700 all=13886 active=1224 piece=▁changing
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=355 min_freq=152
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=350 size=1720 all=13947 active=1062 piece=▁wanted
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=344 size=1740 all=13976 active=1091 piece=rate
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=338 size=1760 all=14023 active=1138 piece=▁smells
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=329 size=1780 all=14094 active=1209 piece=der
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=321 size=1800 all=14149 active=1264 piece=▁True
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=321 min_freq=143
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=313 size=1820 all=14183 active=1035 piece=dden
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=307 size=1840 all=14229 active=1081 piece=▁current
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=301 size=1860 all=14257 active=1109 piece=▁touch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=293 size=1880 all=14347 active=1199 piece=▁store
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=287 size=1900 all=14417 active=1269 piece=▁oven
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=287 min_freq=132
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=284 size=1920 all=14434 active=1017 piece=▁information
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=277 size=1940 all=14492 active=1075 piece=▁homes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=272 size=1960 all=14547 active=1130 piece=▁distract
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=265 size=1980 all=14586 active=1169 piece=▁pen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=261 size=2000 all=14644 active=1227 piece=▁litter
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=260 min_freq=122
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=256 size=2020 all=14684 active=1040 piece=ner
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=250 size=2040 all=14728 active=1084 piece=▁narrow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=247 size=2060 all=14747 active=1103 piece=▁picture
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=241 size=2080 all=14787 active=1143 piece=▁leather
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=237 size=2100 all=14835 active=1191 piece=▁damage
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=237 min_freq=114
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=234 size=2120 all=14835 active=1001 piece=▁hanging
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=228 size=2140 all=14864 active=1030 piece=▁body
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=223 size=2160 all=14883 active=1049 piece=▁prom
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=219 size=2180 all=14948 active=1114 piece=▁burden
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=217 size=2200 all=14965 active=1131 piece=▁frequ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=217 min_freq=107
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=213 size=2220 all=14976 active=1009 piece=▁odd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=210 size=2240 all=14991 active=1024 piece=▁elastic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=207 size=2260 all=15018 active=1051 piece=▁adventures
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=203 size=2280 all=15034 active=1067 piece=▁tran
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=200 size=2300 all=15060 active=1093 piece=▁paths
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=200 min_freq=100
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=197 size=2320 all=15079 active=1020 piece=▁valid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=193 size=2340 all=15104 active=1045 piece=▁arri
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=192 size=2360 all=15136 active=1077 piece=▁unwelcoming
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=189 size=2380 all=15129 active=1070 piece=▁expectations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=185 size=2400 all=15145 active=1086 piece=▁influ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=185 min_freq=94
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=183 size=2420 all=15170 active=1024 piece=▁visiting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=179 size=2440 all=15193 active=1047 piece=▁families
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=176 size=2460 all=15197 active=1051 piece=nds
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=173 size=2480 all=15221 active=1075 piece=▁mindful
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=170 size=2500 all=15241 active=1095 piece=▁finish
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=170 min_freq=88
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=166 size=2520 all=15284 active=1044 piece=▁drop
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=163 size=2540 all=15312 active=1072 piece=▁impulse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=160 size=2560 all=15319 active=1079 piece=▁approach
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=156 size=2580 all=15331 active=1091 piece=▁his
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=154 size=2600 all=15373 active=1133 piece=▁bel
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=154 min_freq=82
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=152 size=2620 all=15412 active=1036 piece=▁sail
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=150 size=2640 all=15445 active=1069 piece=isf
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=2660 all=15459 active=1083 piece=▁valuable
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=2680 all=15489 active=1113 piece=▁organiz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=2700 all=15534 active=1158 piece=▁harbor
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=145 min_freq=76
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=143 size=2720 all=15541 active=1008 piece=aged
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=2740 all=15574 active=1041 piece=▁sugar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=140 size=2760 all=15613 active=1080 piece=▁kinder
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=138 size=2780 all=15618 active=1085 piece=▁constant
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=136 size=2800 all=15650 active=1117 piece=▁limit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=136 min_freq=72
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=2820 all=15671 active=1020 piece=▁card
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=2840 all=15709 active=1058 piece=▁smaller
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=2860 all=15719 active=1068 piece=zz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=2880 all=15780 active=1129 piece=▁round
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=2900 all=15784 active=1133 piece=▁braver
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=126 min_freq=66
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=124 size=2920 all=15837 active=1054 piece=▁secrets
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=2940 all=15872 active=1089 piece=▁flag
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=2960 all=15896 active=1113 piece=▁routine
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=119 size=2980 all=15906 active=1123 piece=▁bed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=3000 all=15919 active=1136 piece=▁styles
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=118 min_freq=62
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=3020 all=15926 active=1008 piece=▁develop
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=3040 all=15956 active=1038 piece=place
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=3060 all=15967 active=1049 piece=▁thrill
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=111 size=3080 all=15990 active=1072 piece=▁silk
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=3100 all=16028 active=1110 piece=▁Eating
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=110 min_freq=58
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=3120 all=16024 active=997 piece=▁Writing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=3140 all=16049 active=1022 piece=▁mud
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=106 size=3160 all=16072 active=1045 piece=▁recipe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104 size=3180 all=16081 active=1054 piece=▁drinking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=3200 all=16082 active=1055 piece=▁connects
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=103 min_freq=54
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=102 size=3220 all=16076 active=995 piece=▁unimportant
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=3240 all=16096 active=1015 piece=▁brass
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=3260 all=16101 active=1020 piece=▁clothing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=3280 all=16104 active=1023 piece=▁closely
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=3300 all=16115 active=1034 piece=▁En
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=96 min_freq=51
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=3320 all=16150 active=1031 piece=▁downs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=3340 all=16156 active=1037 piece=▁Well
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=3360 all=16171 active=1052 piece=▁hoped
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=3380 all=16167 active=1048 piece=▁brought
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=3400 all=16168 active=1049 piece=▁cop
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=90 min_freq=48
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=89 size=3420 all=16185 active=1014 piece=▁indoor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=88 size=3440 all=16194 active=1023 piece=▁mother
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=87 size=3460 all=16213 active=1042 piece=▁military
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=3480 all=16230 active=1059 piece=▁competition
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=3500 all=16245 active=1074 piece=▁fade
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=84 min_freq=45
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=3520 all=16256 active=1012 piece=▁arch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=3540 all=16260 active=1016 piece=iverse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=3560 all=16267 active=1023 piece=▁allow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=3580 all=16287 active=1043 piece=▁manageable
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=3600 all=16306 active=1062 piece=▁gun
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=78 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=3620 all=16295 active=989 piece=▁alarming
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=3640 all=16304 active=998 piece=▁amusement
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=3660 all=16300 active=994 piece=▁reality
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=3680 all=16308 active=1002 piece=▁conflict
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=3700 all=16313 active=1007 piece=▁trapped
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=74 min_freq=39
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=3720 all=16322 active=1010 piece=▁irrit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=3740 all=16333 active=1021 piece=▁chase
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=3760 all=16347 active=1035 piece=▁outing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=3780 all=16348 active=1036 piece=▁brains
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=3800 all=16344 active=1032 piece=▁wom
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=69 min_freq=37
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=3820 all=16340 active=995 piece=▁pred
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=3840 all=16352 active=1007 piece=▁climb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=3860 all=16361 active=1016 piece=▁seat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=3880 all=16354 active=1009 piece=▁kept
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=3900 all=16364 active=1019 piece=dule
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=64 min_freq=34
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=3920 all=16373 active=1008 piece=▁Speaking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=3940 all=16381 active=1016 piece=▁listens
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=3960 all=16401 active=1036 piece=▁jack
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=3980 all=16405 active=1040 piece=▁Can
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=4000 all=16411 active=1046 piece=▁secretary
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=61 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=4020 all=16445 active=1035 piece=▁degree
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=4040 all=16470 active=1060 piece=▁gift
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=4060 all=16502 active=1092 piece=▁didn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=4080 all=16487 active=1077 piece=▁Fl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=4100 all=16512 active=1102 piece=▁refresh
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57 min_freq=30
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=4120 all=16516 active=1005 piece=▁buying
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=4140 all=16518 active=1007 piece=▁eerie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=4160 all=16515 active=1004 piece=▁cute
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=4180 all=16501 active=990 piece=▁performance
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=4200 all=16518 active=1007 piece=▁concert
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=4220 all=16540 active=1022 piece=action
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=4240 all=16543 active=1025 piece=▁customer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=4260 all=16566 active=1048 piece=earing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=4280 all=16571 active=1053 piece=▁opt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=4300 all=16560 active=1042 piece=▁transform
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=50 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=4320 all=16565 active=1001 piece=▁theory
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=4340 all=16582 active=1018 piece=▁Sn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=4360 all=16616 active=1052 piece=▁jacket
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=4380 all=16628 active=1064 piece=ushed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=4400 all=16621 active=1057 piece=▁interactions
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=47 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=4420 all=16633 active=1013 piece=▁mixing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=4440 all=16645 active=1025 piece=▁Wow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=4460 all=16641 active=1021 piece=▁temperatures
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=4480 all=16656 active=1036 piece=▁access
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=4500 all=16670 active=1050 piece=▁abil
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=43 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=4520 all=16662 active=992 piece=▁movements
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=4540 all=16673 active=1003 piece=▁regain
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=4560 all=16662 active=992 piece=▁ur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=4580 all=16694 active=1024 piece=▁reveal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=4600 all=16689 active=1019 piece=eeds
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=40 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=4620 all=16738 active=1046 piece=▁trend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=4640 all=16728 active=1036 piece=▁recommend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=4660 all=16761 active=1069 piece=▁dining
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=4680 all=16763 active=1071 piece=▁La
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=4700 all=16780 active=1088 piece=▁trips
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=38 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=4720 all=16768 active=989 piece=▁strategies
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=4740 all=16779 active=1000 piece=▁Shadows
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=4760 all=16762 active=983 piece=▁experiencing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=4780 all=16794 active=1015 piece=▁pests
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=4800 all=16786 active=1007 piece=▁Education
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=4820 all=16824 active=1039 piece=orthy
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=4840 all=16819 active=1034 piece=▁observe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=4860 all=16820 active=1035 piece=ics
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=4880 all=16829 active=1044 piece=▁waters
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=4900 all=16816 active=1031 piece=▁shoulders
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=34 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=4920 all=16823 active=1008 piece=▁sust
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=4940 all=16823 active=1008 piece=▁bottles
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=4960 all=16824 active=1009 piece=▁sau
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=4980 all=16821 active=1006 piece=▁entirely
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5000 all=16817 active=1002 piece=days
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=31 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5020 all=16840 active=1019 piece=▁heads
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5040 all=16831 active=1010 piece=▁unprepared
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5060 all=16845 active=1024 piece=▁Their
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5080 all=16833 active=1012 piece=▁pencils
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5100 all=16815 active=994 piece=▁maintaining
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=30 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5120 all=16838 active=1024 piece=▁holes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5140 all=16831 active=1017 piece=▁contain
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5160 all=16816 active=1002 piece=▁constantly
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5180 all=16840 active=1026 piece=▁muse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5200 all=16847 active=1033 piece=▁candles
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=28 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5220 all=16832 active=986 piece=▁observations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5240 all=16848 active=1002 piece=engers
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5260 all=16839 active=993 piece=▁arching
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5280 all=16822 active=976 piece=▁highlight
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5300 all=16835 active=989 piece=ster
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=26 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5320 all=16847 active=1009 piece=▁louder
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5340 all=16833 active=995 piece=▁practical
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=5360 all=16863 active=1025 piece=▁adap
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=5380 all=16864 active=1026 piece=▁doubts
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=5400 all=16849 active=1011 piece=▁finishing
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=25 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=5420 all=16866 active=1018 piece=▁Saf
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=5440 all=16882 active=1034 piece=▁aside
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=5460 all=16874 active=1026 piece=▁Comfort
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=5480 all=16863 active=1015 piece=▁background
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=5500 all=16916 active=1068 piece=cies
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=23 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=5520 all=16941 active=1025 piece=▁sink
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=5540 all=16937 active=1021 piece=▁nostal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=5560 all=16923 active=1007 piece=▁lifesty
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=5580 all=16906 active=990 piece=▁comfortably
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=5600 all=16927 active=1011 piece=▁ech
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=5620 all=16941 active=1013 piece=▁input
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=5640 all=16936 active=1008 piece=▁Perfect
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=5660 all=16920 active=992 piece=▁twisting
# trainer_interface.cc(689) LOG(INFO) Saving model: tokenizer.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: tokenizer.vocab
# Tokens: 2965704
# epoch 0 step 0: loss 8.8980
# epoch 0 step 200: loss 4.4125
# epoch 0 step 400: loss 4.0906
# epoch 0 step 600: loss 3.7137
# epoch 0 step 800: loss 3.2911
# epoch 0 step 1000: loss 3.2581
# epoch 0 step 1200: loss 3.4629
# epoch 0 step 1400: loss 3.4502
# epoch 0 step 1600: loss 3.0243
# epoch 0 step 1800: loss 3.4074
# epoch 1 step 0: loss 3.0500
# epoch 1 step 200: loss 2.9522
# epoch 1 step 400: loss 2.9467
# epoch 1 step 600: loss 3.0786
# epoch 1 step 800: loss 2.8551
# epoch 1 step 1000: loss 3.1611
# epoch 1 step 1200: loss 2.9651
# epoch 1 step 1400: loss 3.1160
# epoch 1 step 1600: loss 3.0933
# epoch 1 step 1800: loss 2.8437
# epoch 2 step 0: loss 2.8395
# epoch 2 step 200: loss 2.5759
# epoch 2 step 400: loss 3.0929
# epoch 2 step 600: loss 2.5147
# epoch 2 step 800: loss 2.9133
# epoch 2 step 1000: loss 2.6956
# epoch 2 step 1200: loss 2.6062
# epoch 2 step 1400: loss 2.7903
# epoch 2 step 1600: loss 2.6630
# epoch 2 step 1800: loss 2.6708
# DONE. Saved tinyLM.pt
